# %% [markdown]
# python train.py \
#     --config-dir=ICT/config/ \
#     --config-name=train_dp_ode_hybrid_workspace.yaml \
#     logging.name=dit_ode \
#     logging.project=transport \
#     task=transport_image \
#     horizon=16 \
#     task.env_runner.n_envs=8 \
#     training.seed=42 \
#     training.device=cuda:3 \
#     hydra.run.dir='data/outputs/${now:%Y.%m.%d}/${now:%H.%M.%S}_${name}_${task_name}'

# %% [markdown]
# python train.py \
#     --config-dir=diffusion_policy/config \
#     --config-name=train_diffusion_transformer_ode_hybrid_workspace.yaml \
#     logging.name=trans_ode \
#     logging.project=transport \
#     task=transport_image \
#     horizon=16 \
#     task.env_runner.n_envs=8 \
#     training.seed=42 \
#     training.device=cuda:0 \
#     hydra.run.dir='data/outputs/${now:%Y.%m.%d}/${now:%H.%M.%S}_${name}_${task_name}' \
#     training.rollout_every=200 \
#     training.checkpoint_every=200 \
#     training.val_every=20 \
#     training.sample_every=100 \
#     dataloader.persistent_workers=True \
#     dataloader.batch_size=256 \
#     dataloader.num_workers=16

# %% [markdown]
# python train.py \
#     --config-dir=ICT/config \
#     --config-name=train_dit_ode_hybrid_workspace.yaml \
#     logging.name=dit_ode_v \
#     logging.project=pusht \
#     task=pusht_image \
#     horizon=16 \
#     task.env_runner.n_envs=8 \
#     training.seed=42 \
#     training.device=cuda:2 \
#     hydra.run.dir='data/outputs/${now:%Y.%m.%d}/${now:%H.%M.%S}_${name}_${task_name}' \
#     dataloader.batch_size=256 \
#     dataloader.num_workers=16 \
#     dataloader.persistent_workers=ture

# %%
tmux new -s lerobot
tmux new -s lerobot1
tmux kill-session -t lerobot
tmux new -s dp

# %% [markdown]
# 功能,命令
# 新建会话,tmux new -s <会话名> (建议给训练任务起名，如 train)
# 列出所有会话,tmux ls
# 进入/恢复会话,tmux attach -t <会话名> (简写 tmux a -t ...)
# 重命名会话,tmux rename-session -t <旧名> <新名>
# 关闭/删除会话,tmux kill-session -t <会话名>
